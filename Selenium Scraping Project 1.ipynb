# %% [markdown]
# # DYNAMIC WEB SCRAPPING USING SELENIUM

# %% [markdown]
# # Scrapping the Random Dehydrated Products in Amazon Using Selenium

# %%
# !pip install selenium
from selenium import webdriver
from time import sleep

# %%
path = 'C://chromedriver.exe'

# %%
# open the browser
browser = webdriver.Chrome(executable_path=path)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4272\1682996034.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path=path)

# %%
# load the webpage
browser.get('https://www.amazon.in')

# %%
browser.maximize_window()

# %%
from selenium.webdriver.common.by import By

# %%
# get the input elements

input_search = browser.find_element(By.ID,("twotabsearchtextbox"))
search_button = browser.find_element(By.XPATH,"(//input[@type='submit'])")

# %%
# send the input to the webpage
input_search.send_keys("Dehydrated Foods")
sleep(1)
search_button.click()

# %%
from selenium.webdriver.common.by import By
import selenium.webdriver.support.expected_conditions as ec

# %%
products = []
for i in range(7):
    print('Scraping page', i+1)
    
    product = browser.find_elements(By.XPATH,"(//div[@class='a-section a-spacing-small puis-padding-left-small puis-padding-right-small'])")
    for p in product:
        products.append(p.text)
    next_button = browser.find_elements(By.XPATH,"(//span[@class='s-pagination-item s-pagination-ellipsis'])")
    for chk in next_button:
        chk.click()

    sleep(2)
# Out:
# Scraping page 1
# Scraping page 2
# Scraping page 3
# Scraping page 4
# Scraping page 5
# Scraping page 6
# Scraping page 7

# %%
len(products)
# Out:
# 420

# %%
products
# Out:
# ['Sponsored\nKoinonia KCROASTERS, 120gm X 3 Dark Roast Sampler Pack, Arabica Coffee Beans, Roasted & Ground For Cold Brew, Packed in Biodegradable Bags\n81\n₹750 (₹208.33/100 g)\nSave 5% more with Subscribe & Save\nGet it by Sunday, January 1\nFREE Delivery by Amazon',
#  'Sponsored\nSlurrp Farm Baby Cereal, Ragi, Rice and Strawberry with Milk, Instant Healthy Food, NO Sugar NO Salt, Mildly Sweetened with Date Powder, 200 g\n2,170\nDeal of the Day\n₹270 (₹270/count)\n₹349 (23% off)\nSave 5% more with Subscribe & Save\nGet it by Saturday, December 31\nFREE Delivery by Amazon',
#  'Sponsored\nDesi Naturals Delicious Brown Rice Dosa Powder With Zero Preservatives, No wet grinding Just Mix and Ferment Batter In Water Tasty & Healthy South Indian food Pack of 3 Each 350 G\n₹160 (₹53.33/count)\n₹165 (3% off)\nGet it by Monday, January 2',
# ...

# %%
# WE CAN SEE ALL THE 420 PRODUCTS ABOVE - WE CAN ANALYSE AND STRUCTURE IT USING PANDAS

# %%
#2nd PRODUCTS IN A LIST
(products[1] +"/n")
# Out:
# 'Sponsored\nSlurrp Farm Baby Cereal, Ragi, Rice and Strawberry with Milk, Instant Healthy Food, NO Sugar NO Salt, Mildly Sweetened with Date Powder, 200 g\n2,170\nDeal of the Day\n₹270 (₹270/count)\n₹349 (23% off)\nSave 5% more with Subscribe & Save\nGet it by Saturday, December 31\nFREE Delivery by Amazon/n'

# %%
# SOME LITTLE OPERATIONS
# 1ST PRODUCT IN A LIST
(products[0] +"/n")
# Out:
# 'Sponsored\nKoinonia KCROASTERS, 120gm X 3 Dark Roast Sampler Pack, Arabica Coffee Beans, Roasted & Ground For Cold Brew, Packed in Biodegradable Bags\n81\n₹750 (₹208.33/100 g)\nSave 5% more with Subscribe & Save\nGet it by Sunday, January 1\nFREE Delivery by Amazon/n'

# %%
# we can still perform some operations and extract the only data needed and can convert it into excel using tools like 
# pandas, matplotlib, etc - as this tutorial is only about scrapping, we are not doing the analysis part
